# %% [markdown]
# # Setup

# %% [markdown]
# ## Setup Instructions
#
# These steps may be skipped if the setup has already been completed.
#
# ### Step #1: Install Anaconda
#
# Download and install the latest version of Anaconda from:
# 👉 https://www.anaconda.com/
#
# The current version of Anaconda is Anaconda 3.
#
# After installation and running Anaconda, you will get a similar environment where Jupyter and Spyder are already installed.
# These are the target tools for this course.
#
# ### Step #2: Start Jupyter or Spyder for Python
#
# You can start Jupyter or Spyder in one of the following ways:
#
# From the Anaconda GUI (this is the most time-consuming method)
#
# Directly from the Start Menu without opening Anaconda
#
# ### Step #3: Install Libraries / Packages in Python
#
# During your work, you will frequently need Python libraries/packages.
# The required libraries for this course are:
#
# SkyPi
#
# OpenCV
#
# scikit-image
#
# Pillow
#
# Matplotlib
#
# ### Step #4: Install NumPy
#
# Search for NumPy using Google.
#
# One of the official links is:
# 👉 https://pypi.org/project/numpy/
#
# Copy the installation command from the website.
#
# Paste it into the command prompt of Jupyter or Spyder.
#
# NumPy will be installed locally.

# %% [markdown]
# # Review and practice the two Python cheat sheets

# %% [markdown]
# [NumPy Python Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf)

# %% [markdown]
# # NumPy Exercises
#
# Now that we've learned about NumPy let's test your knowledge. We'll start off with a few simple tasks, and then you'll be asked some more complicated questions.

# %% [markdown]
# #### Import NumPy as np

# %%
import numpy as np

# %% [markdown]
# #### Create an array of 10 zeros

# %%
np.zeros(10)

# %% [markdown]
# #### Create an array of 10 ones

# %%
np.ones(10)

# %% [markdown]
# #### Create an array of 10 fives

# %%
np.ones(10) * 5

# %% [markdown]
# #### Create an array of the integers from 10 to 50

# %%
np.arange(10, 51)

# %% [markdown]
# #### Create an array of all the even integers from 10 to 50

# %%
np.arange(10, 51, 2)

# %% [markdown]
# #### Create a 3x3 matrix with values ranging from 0 to 8

# %%
np.arange(9).reshape(3, 3)

# %% [markdown]
# #### Create a 3x3 identity matrix

# %%
np.eye(3)

# %% [markdown]
# #### Use NumPy to generate a random number between 0 and 1

# %%
np.random.rand(1)

# %% [markdown]
# #### Use NumPy to generate an array of 25 random numbers sampled from a standard normal distribution

# %%
np.random.randn(25)

# %% [markdown]
# #### Create the following matrix:

# %%
np.arange(1, 101).reshape(10, 10) / 100

# %% [markdown]
# #### Create an array of 20 linearly spaced points between 0 and 1:

# %%
np.linspace(0, 1, 20)

# %% [markdown]
# ## NumPy Indexing and Selection
#
# Now you will be given a few matrices, and be asked to replicate the resulting matrix outputs:

# %%
mat = np.arange(1, 26).reshape(5, 5)
mat

# %%
mat[2:, 1:]

# %%
mat[3, 4]

# %%
mat[:3, 1:2]

# %%
mat[4, :]

# %%
mat[3:, :]

# %% [markdown]
# ### Now do the following

# %% [markdown]
# #### Get the sum of all the values in mat

# %%
mat.sum()

# %% [markdown]
# #### Get the standard deviation of the values in mat

# %%
mat.std()

# %% [markdown]
# #### Get the sum of all the columns in mat

# %%
mat.sum(axis=0)

# %% [markdown]
# # Great Job!

# %% [markdown]
# # Image Processing Lab

# %% [markdown]
# # Task #1: Importing Required Libraries
#
# We will be using three main libraries for image processing:
# 1. **NumPy** - For numerical operations and array manipulation
# 2. **OpenCV (cv2)** - A powerful library for image processing
# 3. **PIL (Pillow)** - Python Imaging Library for image handling
# 4. **Matplotlib** - For displaying images
#
# Let's import them one by one.

# %% [markdown]
# ### a. Import NumPy
# NumPy is the fundamental package for scientific computing in Python.

# %%
import numpy as np

# %% [markdown]
# ### b. Import OpenCV (cv2)
# OpenCV is an open-source computer vision library.

# %%
import cv2

# %% [markdown]
# ### c. Import PIL (Pillow)
# PIL is the Python Imaging Library used for opening, manipulating, and saving images.

# %%
from PIL import Image

# %% [markdown]
# # Task #2: Image Loading and Displaying

# %% [markdown]
# ### a. Loading an image using OpenCV

# %%
img = cv2.imread('images/lena_gray_256.png')

# %% [markdown]
# ### b. Displaying image using OpenCV

# %%
cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### c. Loading and displaying image using PIL and Matplotlib

# %%
from PIL import Image
img2 = Image.open('images/lena_gray_256.png')

import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap=cm.Greys_r)
plt.show()

# %% [markdown]
# # Task #3: Image Storing

# %% [markdown]
# a.	Saving image to disc using OpenCV

# %%
cv2.imwrite('new_image.jpg', img)

# %% [markdown]
# b.	Saving image to disc using PIL

# %%
img2.save('new_image2.jpg')

# %% [markdown]
# # Task #4: Display image as an Array

# %%
print(img.shape)
print(img)

# %%
import numpy as np
img_array = np.array(img2)

# %%
print(img_array.shape)
print(img_array)

# %% [markdown]
# ##

# %% [markdown]
# # Task #5: Save your work

# %% [markdown]
# in the terminal, write:
#
# ```bash
# git add .
# git commit -m "Completed lab1 tutorial"
# git push origin master
# ```
